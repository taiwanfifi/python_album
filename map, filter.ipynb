# %%
def even(x):
    return x%2==0
list(map(even, range(10)))
# Out:
# [True, False, True, False, True, False, True, False, True, False]

# %%
list(map(lambda x:x%2==0, range(10)))
# Out:
# [True, False, True, False, True, False, True, False, True, False]

# %%
list(map(lambda x:x**2, range(10)))
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
list(filter(even, range(15)))
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %%
nums =  [1,0,1,1,0,1]
nums = ''.join(map(str, nums))
len(max(nums.split("0")))
nums
# Out:
# '101101'

# %% [markdown]
# ### randit

# %%
from random import randint
[randint(0, 10) for i in range(1000)]
# Out:
# [5,
#  6,
#  1,
#  9,
#  2,
#  0,
#  10,
#  3,
#  5,
#  10,
#  0,
#  3,
#  0,
#  3,
#  9,
#  7,
#  8,
#  1,
#  5,
#  2,
#  9,
#  4,
#  9,
#  4,
#  10,
#  5,
#  5,
#  5,
#  2,
#  7,
#  1,
#  1,
#  7,
#  1,
#  2,
#  10,
#  7,
#  1,
#  10,
#  10,
#  7,
#  1,
#  5,
#  4,
#  4,
#  8,
#  7,
#  8,
#  4,
#  9,
#  6,
#  7,
#  2,
#  9,
#  6,
#  0,
#  5,
#  9,
#  5,
#  6,
#  5,
#  6,
#  4,
#  8,
#  10,
#  3,
#  4,
#  0,
#  7,
#  10,
#  4,
#  1,
#  4,
#  5,
#  9,
#  10,
#  10,
#  9,
#  3,
#  9,
#  9,
#  2,
#  8,
#  3,
#  10,
#  10,
#  5,
#  8,
#  7,
#  0,
#  6,
#  10,
#  6,
#  0,
#  10,
#  1,
#  9,
#  8,
#  3,
#  1,
#  6,
#  1,
#  1,
#  2,
#  6,
#  7,
#  0,
#  8,
#  9,
#  0,
#  2,
#  4,
#  6,
#  9,
#  10,
#  4,
#  7,
#  8,
#  7,
#  1,
#  9,
#  9,
#  5,
#  4,
#  2,
#  1,
#  5,
#  7,
#  9,
#  2,
#  8,
#  5,
#  1,
#  7,
#  10,
#  7,
#  1,
#  2,
#  1,
#  6,
#  10,
#  0,
#  3,
#  3,
#  1,
#  0,
#  3,
#  7,
#  3,
#  1,
#  8,
#  6,
#  7,
#  0,
#  4,
#  10,
#  7,
#  7,
#  5,
#  0,
#  1,
#  0,
#  7,
#  4,
#  9,
#  1,
#  1,
#  5,
#  7,
#  0,
#  8,
#  7,
#  8,
#  1,
#  1,
#  4,
#  10,
#  2,
#  7,
#  4,
#  7,
#  0,
#  10,
#  6,
#  0,
#  4,
#  8,
#  10,
#  2,
#  5,
#  7,
#  5,
#  9,
#  4,
#  4,
#  9,
#  4,
#  2,
#  8,
#  1,
#  1,
#  6,
#  5,
#  1,
#  1,
#  10,
#  5,
#  0,
#  9,
#  1,
#  2,
#  6,
#  4,
#  1,
#  6,
#  5,
#  8,
#  10,
#  9,
#  8,
#  0,
#  6,
#  5,
#  10,
#  10,
#  6,
#  7,
#  1,
#  4,
#  0,
#  8,
#  3,
#  5,
#  9,
#  8,
#  2,
#  0,
#  8,
#  2,
#  8,
#  0,
#  0,
#  4,
#  9,
#  5,
#  4,
#  7,
#  5,
#  1,
#  2,
#  6,
#  5,
#  4,
#  1,
#  0,
#  8,
#  6,
#  9,
#  1,
#  0,
#  2,
#  4,
#  4,
#  5,
#  0,
#  4,
#  4,
#  10,
#  0,
#  10,
#  8,
#  7,
#  4,
#  3,
#  1,
#  7,
#  9,
#  6,
#  5,
#  7,
#  8,
#  10,
#  0,
#  3,
#  4,
#  2,
#  3,
#  4,
#  10,
#  0,
#  4,
#  2,
#  3,
#  0,
#  9,
#  0,
#  8,
#  7,
#  10,
#  7,
#  2,
#  0,
#  8,
#  8,
#  10,
#  9,
#  7,
#  2,
#  6,
#  0,
#  1,
#  4,
#  2,
#  2,
#  7,
#  1,
#  10,
#  4,
#  2,
#  10,
#  1,
#  0,
#  4,
#  4,
#  10,
#  6,
#  5,
#  0,
#  10,
#  9,
#  7,
#  4,
#  8,
#  2,
#  4,
#  8,
#  0,
#  3,
#  9,
#  1,
#  3,
#  7,
#  1,
#  9,
#  10,
#  9,
#  6,
#  4,
#  7,
#  2,
#  6,
#  2,
#  8,
#  9,
#  10,
#  8,
#  1,
#  4,
#  9,
#  6,
#  0,
#  8,
#  5,
#  9,
#  10,
#  1,
#  4,
#  0,
#  1,
#  8,
#  4,
#  3,
#  1,
#  6,
#  2,
#  10,
#  5,
#  6,
#  0,
#  3,
#  3,
#  7,
#  8,
#  9,
#  10,
#  9,
#  7,
#  9,
#  9,
#  7,
#  3,
#  8,
#  5,
#  1,
#  3,
#  1,
#  6,
#  4,
#  2,
#  5,
#  1,
#  0,
#  3,
#  5,
#  8,
#  4,
#  5,
#  6,
#  4,
#  10,
#  9,
#  4,
#  10,
#  2,
#  7,
#  2,
#  9,
#  9,
#  1,
#  9,
#  3,
#  5,
#  7,
#  8,
#  0,
#  3,
#  10,
#  10,
#  8,
#  6,
#  0,
#  4,
#  7,
#  7,
#  0,
#  2,
#  6,
#  3,
#  10,
#  3,
#  4,
#  0,
#  0,
#  3,
#  2,
#  4,
#  5,
#  0,
#  4,
#  3,
#  4,
#  0,
#  1,
#  7,
#  0,
#  9,
#  7,
#  0,
#  2,
#  7,
#  2,
#  9,
#  3,
#  3,
#  3,
#  2,
#  7,
#  9,
#  6,
#  10,
#  7,
#  1,
#  10,
#  1,
#  1,
#  2,
#  8,
#  1,
#  8,
#  1,
#  7,
#  1,
#  5,
#  8,
#  8,
#  8,
#  3,
#  4,
#  8,
#  10,
#  4,
#  3,
#  9,
#  1,
#  9,
#  7,
#  6,
#  3,
#  7,
#  9,
#  9,
#  2,
#  5,
#  4,
#  2,
#  1,
#  0,
#  10,
#  1,
#  4,
#  3,
#  10,
#  5,
#  9,
#  7,
#  10,
#  7,
#  4,
#  10,
#  2,
#  7,
#  6,
#  5,
#  4,
#  0,
#  0,
#  8,
#  2,
#  6,
#  5,
#  5,
#  3,
#  10,
#  9,
#  2,
#  5,
#  3,
#  10,
#  5,
#  7,
#  4,
#  1,
#  6,
#  0,
#  7,
#  6,
#  9,
#  9,
#  4,
#  10,
#  3,
#  4,
#  9,
#  0,
#  9,
#  1,
#  6,
#  7,
#  10,
#  4,
#  10,
#  2,
#  5,
#  10,
#  2,
#  4,
#  7,
#  4,
#  1,
#  8,
#  7,
#  4,
#  8,
#  0,
#  2,
#  0,
#  0,
#  6,
#  1,
#  6,
#  2,
#  0,
#  1,
#  7,
#  0,
#  2,
#  5,
#  1,
#  0,
#  2,
#  0,
#  1,
#  10,
#  6,
#  7,
#  3,
#  3,
#  7,
#  7,
#  7,
#  2,
#  7,
#  8,
#  8,
#  8,
#  2,
#  5,
#  7,
#  5,
#  9,
#  5,
#  5,
#  6,
#  4,
#  9,
#  9,
#  9,
#  4,
#  9,
#  1,
#  8,
#  6,
#  2,
#  2,
#  0,
#  4,
#  0,
#  2,
#  8,
#  3,
#  6,
#  3,
#  1,
#  10,
#  1,
#  1,
#  10,
#  9,
#  3,
#  7,
#  5,
#  2,
#  0,
#  0,
#  6,
#  7,
#  0,
#  9,
#  0,
#  0,
#  1,
#  0,
#  2,
#  9,
#  0,
#  0,
#  9,
#  2,
#  6,
#  4,
#  3,
#  1,
#  6,
#  6,
#  6,
#  10,
#  9,
#  2,
#  10,
#  1,
#  2,
#  1,
#  3,
#  0,
#  6,
#  6,
#  3,
#  10,
#  3,
#  1,
#  7,
#  4,
#  7,
#  9,
#  6,
#  8,
#  5,
#  0,
#  10,
#  0,
#  4,
#  3,
#  2,
#  5,
#  5,
#  10,
#  7,
#  9,
#  8,
#  4,
#  1,
#  10,
#  3,
#  5,
#  4,
#  9,
#  4,
#  3,
#  8,
#  7,
#  8,
#  3,
#  2,
#  3,
#  9,
#  4,
#  8,
#  0,
#  7,
#  0,
#  2,
#  5,
#  6,
#  1,
#  4,
#  3,
#  7,
#  8,
#  7,
#  9,
#  3,
#  10,
#  8,
#  4,
#  9,
#  2,
#  10,
#  8,
#  3,
#  10,
#  2,
#  0,
#  10,
#  9,
#  4,
#  8,
#  5,
#  9,
#  1,
#  1,
#  4,
#  2,
#  8,
#  3,
#  2,
#  6,
#  4,
#  0,
#  3,
#  6,
#  1,
#  0,
#  0,
#  5,
#  4,
#  8,
#  1,
#  6,
#  9,
#  0,
#  0,
#  9,
#  10,
#  4,
#  3,
#  1,
#  9,
#  7,
#  6,
#  2,
#  4,
#  3,
#  1,
#  2,
#  2,
#  0,
#  7,
#  1,
#  5,
#  4,
#  2,
#  9,
#  0,
#  3,
#  6,
#  0,
#  2,
#  9,
#  0,
#  0,
#  1,
#  9,
#  3,
#  3,
#  7,
#  6,
#  5,
#  6,
#  2,
#  3,
#  6,
#  10,
#  7,
#  10,
#  7,
#  8,
#  7,
#  8,
#  1,
#  9,
#  6,
#  8,
#  8,
#  8,
#  3,
#  6,
#  6,
#  8,
#  4,
#  1,
#  5,
#  9,
#  10,
#  1,
#  3,
#  7,
#  9,
#  6,
#  4,
#  3,
#  0,
#  8,
#  3,
#  2,
#  6,
#  1,
#  2,
#  0,
#  10,
#  5,
#  2,
#  5,
#  5,
#  1,
#  0,
#  9,
#  2,
#  2,
#  7,
#  5,
#  1,
#  3,
#  6,
#  1,
#  0,
#  1,
#  7,
#  4,
#  6,
#  4,
#  8,
#  6,
#  10,
#  9,
#  6,
#  10,
#  8,
#  6,
#  4,
#  6,
#  6,
#  10,
#  3,
#  4,
#  4,
#  3,
#  3,
#  1,
#  0,
#  3,
#  0,
#  7,
#  4,
#  10,
#  5,
#  10,
#  9,
#  5,
#  10,
#  4,
#  5,
#  10,
#  6,
#  6,
#  2,
#  10,
#  8,
#  10,
#  1,
#  4,
#  10,
#  2,
#  0,
#  6,
#  9,
#  1,
#  8,
#  2,
#  1,
#  1,
#  0,
#  0,
#  1,
#  5,
#  8,
#  8,
#  6,
#  10,
#  5,
#  1,
#  7,
#  2,
#  1,
#  8,
#  2,
#  10,
#  8,
#  2,
#  1,
#  3,
#  5,
#  9,
#  6,
#  6,
#  8,
#  6,
#  2,
#  3,
#  9,
#  10,
#  9,
#  6,
#  10,
#  1,
#  5,
#  3,
#  2,
#  10,
#  3,
#  3,
#  0,
#  5,
#  10,
#  3,
#  0,
#  5,
#  10,
#  3,
#  6,
#  10,
#  9,
#  0,
#  1,
#  8,
#  3,
#  1,
#  6,
#  4,
#  3,
#  7,
#  5,
#  7,
#  2,
#  6,
#  4,
#  10,
#  10,
#  2,
#  0,
#  3,
#  4,
#  1,
#  1,
#  10,
#  4,
#  6,
#  7,
#  6,
#  0,
#  8]
